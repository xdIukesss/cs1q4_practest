# %% [markdown]
# <a href="https://colab.research.google.com/github/xdIukesss/cs1q4_practest/blob/main/cs1q4_practicaltest.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("What is your name?")
input("name")
print("How many quiz scores would you like to input")
num_scores_str = int(input("Enter how many scores you will input"))
scores = []
for num_scores_str in range(num_scores_str):
 score_input = input("Enter score")
 score = int(score_input)
 scores.append(score)
 print(scores)
 sum_scores = sum(scores)
 print(sum_scores)
 if (sum_scores) >= 75:
   print("You passed")
 else:
  print("You failed")
# Out:
# What is your name?
# name3
# How many quiz scores would you like to input
# Enter how many scores you will input3
# Enter score23
# [23]
# 23
# You failed
# Enter score43
# [23, 43]
# 66
# You failed
# Enter score21
# [23, 43, 21]
# 87
# You passed
